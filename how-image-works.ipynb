# %%
import numpy as np

# %%
from PIL import Image #python Image library
import matplotlib #
import cv2

# %%
# !pip install pillow
# Out:
# Collecting pillow
#   Downloading https://files.pythonhosted.org/packages/05/8a/097d6d7d9b1e947d7b39f269d85491e7a756ceedac57dd1bd6f3d69a61d8/Pillow-7.1.2-cp36-cp36m-macosx_10_10_x86_64.whl (2.2MB)
#     100% |████████████████████████████████| 2.2MB 3.8MB/s ta 0:00:01
# Installing collected packages: pillow
# Successfully installed pillow-7.1.2
# You are using pip version 18.1, however version 20.2b1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading https://files.pythonhosted.org/packages/8f/67/d30cb5ee1210c6778a718780d227fa27fa066b46cc25e0b09cd8e51faffe/opencv_python-4.2.0.34-cp36-cp36m-macosx_10_9_x86_64.whl (49.1MB)
#     100% |████████████████████████████████| 49.1MB 619kB/s eta 0:00:01    50% |████████████████▎               | 25.0MB 26.8MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.11.3 in ./facedetectvm/lib/python3.6/site-packages (from opencv-python) (1.19.0)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.2.0.34
# You are using pip version 18.1, however version 20.2b1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
img = Image.open('./data/parrot.jpg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=626x352 at 0x7F92D03D5400>

# %%
#loading using matplotlib: (RBG)
from matplotlib import image
img_mat = matplotlib.image.imread("./data/parrot.jpg")

# %%
img_mat
# Out:
# array([[[109,  95,  66],
#         [109,  95,  66],
#         [106,  95,  65],
#         ...,
#         [102,  92,  67],
#         [101,  93,  70],
#         [101,  93,  70]],
#
#        [[109,  95,  66],
#         [109,  95,  66],
#         [106,  95,  65],
#         ...,
#         [102,  92,  67],
#         [100,  92,  69],
#         [100,  92,  69]],
#
#        [[108,  94,  65],
#         [108,  94,  65],
#         [105,  94,  64],
#         ...,
#         [100,  93,  67],
#         [100,  93,  67],
#         [100,  93,  67]],
#
#        ...,
#
#        [[ 47,  89,  25],
#         [ 47,  89,  25],
#         [ 48,  90,  26],
#         ...,
#         [ 92,  95,  50],
#         [ 93,  96,  51],
#         [ 93,  96,  51]],
#
#        [[ 48,  90,  26],
#         [ 48,  90,  26],
#         [ 49,  91,  27],
#         ...,
#         [ 92,  95,  50],
#         [ 93,  96,  51],
#         [ 93,  96,  51]],
#
#        [[ 49,  91,  25],
#         [ 49,  91,  25],
#         [ 49,  91,  25],
#         ...,
#         [ 94,  95,  51],
#         [ 93,  96,  51],
#         [ 93,  96,  51]]], dtype=uint8)

# %%
#read image using openCV : BGR (Blue Green and REd)
img_cv = cv2.imread('./data/parrot.jpg')

# %%
img_cv
# Out:
# array([[[ 66,  95, 109],
#         [ 66,  95, 109],
#         [ 65,  95, 106],
#         ...,
#         [ 67,  92, 102],
#         [ 70,  93, 101],
#         [ 70,  93, 101]],
#
#        [[ 66,  95, 109],
#         [ 66,  95, 109],
#         [ 65,  95, 106],
#         ...,
#         [ 67,  92, 102],
#         [ 69,  92, 100],
#         [ 69,  92, 100]],
#
#        [[ 65,  94, 108],
#         [ 65,  94, 108],
#         [ 64,  94, 105],
#         ...,
#         [ 67,  93, 100],
#         [ 67,  93, 100],
#         [ 67,  93, 100]],
#
#        ...,
#
#        [[ 25,  89,  47],
#         [ 25,  89,  47],
#         [ 26,  90,  48],
#         ...,
#         [ 50,  95,  92],
#         [ 51,  96,  93],
#         [ 51,  96,  93]],
#
#        [[ 24,  90,  48],
#         [ 24,  90,  48],
#         [ 25,  91,  49],
#         ...,
#         [ 50,  94,  93],
#         [ 51,  96,  93],
#         [ 51,  96,  93]],
#
#        [[ 25,  91,  49],
#         [ 25,  91,  49],
#         [ 25,  91,  49],
#         ...,
#         [ 51,  95,  94],
#         [ 51,  96,  93],
#         [ 51,  96,  93]]], dtype=uint8)

# %%
#displaying images
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.imshow(img_mat) #rgb

# %%
plt.imshow(img_cv)

# %%
img_mat.shape
# Out:
# (352, 626, 3)

# %%
#analyzing image by matplotlib
#split array into three parts
r = img_mat[:,:,0] # red array
g = img_mat[:,:,1] # green array
b = img_mat[:,:,2] # blue array

# %%
r.shape, g.shape, b.shape
# Out:
# ((352, 626), (352, 626), (352, 626))

# %%
plt.figure(figsize=(10,6))
plt.subplot(1,3,1)
plt.title('Red Region')
plt.imshow(r,c,a[])
