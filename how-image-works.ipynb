# %%
import numpy as np

# %%
from PIL import Image #python Image library
import matplotlib #
import cv2

# %%
# !pip install pillow
# Out:
# Requirement already satisfied: pillow in ./facedetectvm/lib/python3.6/site-packages (7.1.2)
# You are using pip version 18.1, however version 20.2b1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in ./facedetectvm/lib/python3.6/site-packages (4.2.0.34)
# Requirement already satisfied: numpy>=1.11.3 in ./facedetectvm/lib/python3.6/site-packages (from opencv-python) (1.19.0)
# You are using pip version 18.1, however version 20.2b1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
img = Image.open('./data/parrot.jpg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=626x352 at 0x7FED3DF535C0>

# %%
#loading using matplotlib: (RBG)
from matplotlib import image
img_mat = matplotlib.image.imread("./data/parrot.jpg")

# %%
img_mat
# Out:
# array([[[109,  95,  66],
#         [109,  95,  66],
#         [106,  95,  65],
#         ...,
#         [102,  92,  67],
#         [101,  93,  70],
#         [101,  93,  70]],
#
#        [[109,  95,  66],
#         [109,  95,  66],
#         [106,  95,  65],
#         ...,
#         [102,  92,  67],
#         [100,  92,  69],
#         [100,  92,  69]],
#
#        [[108,  94,  65],
#         [108,  94,  65],
#         [105,  94,  64],
#         ...,
#         [100,  93,  67],
#         [100,  93,  67],
#         [100,  93,  67]],
#
#        ...,
#
#        [[ 47,  89,  25],
#         [ 47,  89,  25],
#         [ 48,  90,  26],
#         ...,
#         [ 92,  95,  50],
#         [ 93,  96,  51],
#         [ 93,  96,  51]],
#
#        [[ 48,  90,  26],
#         [ 48,  90,  26],
#         [ 49,  91,  27],
#         ...,
#         [ 92,  95,  50],
#         [ 93,  96,  51],
#         [ 93,  96,  51]],
#
#        [[ 49,  91,  25],
#         [ 49,  91,  25],
#         [ 49,  91,  25],
#         ...,
#         [ 94,  95,  51],
#         [ 93,  96,  51],
#         [ 93,  96,  51]]], dtype=uint8)

# %%
#read image using openCV : BGR (Blue Green and REd)
img_cv = cv2.imread('./data/parrot.jpg')

# %%
img_cv
# Out:
# array([[[ 66,  95, 109],
#         [ 66,  95, 109],
#         [ 65,  95, 106],
#         ...,
#         [ 67,  92, 102],
#         [ 70,  93, 101],
#         [ 70,  93, 101]],
#
#        [[ 66,  95, 109],
#         [ 66,  95, 109],
#         [ 65,  95, 106],
#         ...,
#         [ 67,  92, 102],
#         [ 69,  92, 100],
#         [ 69,  92, 100]],
#
#        [[ 65,  94, 108],
#         [ 65,  94, 108],
#         [ 64,  94, 105],
#         ...,
#         [ 67,  93, 100],
#         [ 67,  93, 100],
#         [ 67,  93, 100]],
#
#        ...,
#
#        [[ 25,  89,  47],
#         [ 25,  89,  47],
#         [ 26,  90,  48],
#         ...,
#         [ 50,  95,  92],
#         [ 51,  96,  93],
#         [ 51,  96,  93]],
#
#        [[ 24,  90,  48],
#         [ 24,  90,  48],
#         [ 25,  91,  49],
#         ...,
#         [ 50,  94,  93],
#         [ 51,  96,  93],
#         [ 51,  96,  93]],
#
#        [[ 25,  91,  49],
#         [ 25,  91,  49],
#         [ 25,  91,  49],
#         ...,
#         [ 51,  95,  94],
#         [ 51,  96,  93],
#         [ 51,  96,  93]]], dtype=uint8)

# %%
#displaying images
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.imshow(img_mat) #rgb

# %%
plt.imshow(img_cv)

# %%
img_mat.shape
# Out:
# (352, 626, 3)

# %%
#analyzing image by matplotlib
#split array into three parts
r = img_mat[:,:,0] # red array
g = img_mat[:,:,1] # green array
b = img_mat[:,:,2] # blue array

# %%
r.shape, g.shape, b.shape
# Out:
# ((352, 626), (352, 626), (352, 626))

# %%
plt.figure(figsize=(10,6))
plt.subplot(1,3,1)
plt.title('Red Region')
plt.imshow(r,cmap='gray')
plt.subplot(1,3,2)
plt.title('Green Region')
plt.imshow(g,cmap='gray')
plt.subplot(1,3,3)
plt.title('Blue Region')
plt.imshow(b,cmap='gray')
plt.show()

# %%
#gray scale: 2d
gray_MAT = cv2.cvtColor(img_mat, cv2.COLOR_RGB2GRAY)

# %%
gray_CV = cv2.cvtColor(img_cv, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray_MAT, cmap='gray')

# %%
plt.imshow(gray_CV, cmap='gray')

# %%
gray_CV
# Out:
# array([[96, 96, 95, ..., 92, 93, 93],
#        [96, 96, 95, ..., 92, 92, 92],
#        [95, 95, 94, ..., 92, 92, 92],
#        ...,
#        [69, 69, 70, ..., 89, 90, 90],
#        [70, 70, 71, ..., 89, 90, 90],
#        [71, 71, 71, ..., 90, 90, 90]], dtype=uint8)

# %%
gray_MAT.shape, gray_CV.shape
# Out:
# ((352, 626), (352, 626))

# %%
img_cv.shape
# Out:
# (352, 626, 3)
